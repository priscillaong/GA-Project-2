# %% [markdown]
# # Content

# %% [markdown]
# 1. Problem Statement <br>
#
# 2. Background <br>
#
# 3. Dataset <br>
#
# 3. Data Cleaning<br>
#
# 4. Data Dictionary

# %% [markdown]
# # 1. Problem Statement

# %% [markdown]
# We are the Data team working at NexRes which is a property portal trusted for its extensive listings and comprehensive market information on residential property in Iowa. <br><br>
# The aim of this project is to develop a Regression model that can predict to at least 80% accuracy of Iowa property prices by analysing and narrowing down a list of 80 housing features. <br><br>
# This would help agents registered under NexRes to predict property sale prices and use this predictor to advise clients to optimise property for sale and maximise profits of their property. <br><br>
# It is imperative for us to develop this model to maintain our status in the growing industry and empower our agents to continue providing top value to our clients, who rely on us to secure the best deal.

# %% [markdown]
# # 2. Background

# %% [markdown]
# Ames is a city in Iowa with a population of 65,000 people. She offers cultural, recreational, educational, business, and entertainment amenities more common in bigger metros. Ames is home to Iowa State University, existing businesses such as 3M, Barilla and Becker Underwood and offers four seasons of recreational activities through more than 36 parks, 55 miles of bike trails and golf courses. ([*source*](https://www.cityofames.org/about-ames/about-ames))
#
# Some of the factors which influence saleprice of property would include location, home size and usable space, age and condition of the house, upgrades to the house. ([*source*](https://www.opendoor.com/w/blog/factors-that-influence-home-value))

# %% [markdown]
# # 3. Dataset

# %% [markdown]
# train.csv: Data set contains information from the Ames Assessor’s Office used in computing assessed values for individual residential properties sold in Ames, Iowa from 2006 to 2010.
#
# test.csv: Data set contains all columns of train.csv except for the SalePrice column which is to be predicted via our chosen model and uploaded to Kaggle.

# %% [markdown]
# # 4. Data Cleaning

# %%
#Import Libraries
import pandas as pd

#Suppress Warnings
import warnings
warnings.filterwarnings('ignore')

#Adjust the max columns displayed in the df
pd.set_option("display.max_columns", 85)

# %% [markdown]
# Import train file into df for data cleaning

# %%
df_train = pd.read_csv("../Dataset/train.csv")

# %% [markdown]
# Taking a look at the general shape of the df

# %%
df_train.shape
# Out:
# (2051, 81)

# %% [markdown]
# Taking a look at the first few records of df

# %%
df_train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %% [markdown]
# Further info on the columns and their dtypes

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
# ...

# %% [markdown]
# ## Check for Null Values

# %%
df_train[df_train.columns[df_train.isnull().any()]].isnull().sum()
# Out:
# Lot Frontage       330
# Alley             1911
# Mas Vnr Type        22
# Mas Vnr Area        22
# Bsmt Qual           55
# Bsmt Cond           55
# Bsmt Exposure       58
# BsmtFin Type 1      55
# BsmtFin SF 1         1
# BsmtFin Type 2      56
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1000
# Garage Type        113
# Garage Yr Blt      114
# Garage Finish      114
# Garage Cars          1
# Garage Area          1
# Garage Qual        114
# Garage Cond        114
# Pool QC           2042
# Fence             1651
# Misc Feature      1986
# dtype: int64

# %% [markdown]
# Null values as a percentage of total number of records

# %%
df_train[df_train.columns[df_train.isnull().any()]].isnull().sum() * 100 / df_train.shape[0]
# Out:
# Lot Frontage      16.089712
# Alley             93.174061
# Mas Vnr Type       1.072647
# Mas Vnr Area       1.072647
# Bsmt Qual          2.681619
# Bsmt Cond          2.681619
# Bsmt Exposure      2.827889
# BsmtFin Type 1     2.681619
# BsmtFin SF 1       0.048757
# BsmtFin Type 2     2.730375
# BsmtFin SF 2       0.048757
# Bsmt Unf SF        0.048757
# Total Bsmt SF      0.048757
# Bsmt Full Bath     0.097513
# Bsmt Half Bath     0.097513
# Fireplace Qu      48.756704
# Garage Type        5.509508
# Garage Yr Blt      5.558264
# Garage Finish      5.558264
# Garage Cars        0.048757
# Garage Area        0.048757
# Garage Qual        5.558264
# Garage Cond        5.558264
# Pool QC           99.561190
# Fence             80.497318
# Misc Feature      96.830814
# dtype: float64

# %% [markdown]
# Remove columns where >80% of column is null and save as new df: df_train_clean

# %%
df_train_clean = df_train.drop(labels=['Alley', 'Pool QC', 'Fence', 'Misc Feature'], axis = 1)

# %% [markdown]
# ## Impute Missing Values

# %% [markdown]
# Take a look at Lot frontage which has null values and its lot area

# %%
df_train_clean[df_train_clean["Lot Frontage"].isnull()].head()
# Out:
#       Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    109  533352170           60        RL           NaN     13517   Pave
# 7    145  535154050           20        RL           NaN     12160   Pave
# 8   1942  535353130           20        RL           NaN     15783   Pave
# 23    12  527165230           20        RL           NaN      7980   Pave
# 27  1534  909277040           50        RL           NaN     11700   Pave
#
#    Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0        IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 7        IR1          Lvl    AllPub     Inside        Gtl        NAmes
# 8        Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 23       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 27       IR1          HLS    AllPub     Inside        Mod      Crawfor
#
#    Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %% [markdown]
# To replace Lot Frontage with its median (should not be null since there is a value for lot area)

# %%
median = df_train_clean['Lot Frontage'].median()
df_train_clean['Lot Frontage'] = df_train_clean['Lot Frontage'].fillna(median)

# %% [markdown]
# Mas Vnr Type and Mas Vnr Area has 22 null values, to fill the null values with None and 0

# %%
df_train_clean['Mas Vnr Type'] = df_train_clean['Mas Vnr Type'].fillna("None")
df_train_clean['Mas Vnr Area'] = df_train_clean['Mas Vnr Area'].fillna(0.0)

# %% [markdown]
# To address the null values in the basement variables: <br>
# To remove rows 1456, 1547 and 1997 as only basement exposure info is missing in these rows

# %%
df_train_clean[["Bsmt Qual", "Bsmt Cond", "Bsmt Exposure", "BsmtFin Type 1", "BsmtFin SF 1", "BsmtFin Type 2", "BsmtFin SF 2", "Bsmt Unf SF", "Total Bsmt SF"]].iloc[[1456, 1547, 1997]]
# Out:
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 1456        Gd        TA           NaN            Unf           0.0
# 1547        Gd        TA           NaN            Unf           0.0
# 1997        Gd        TA           NaN            Unf           0.0
#
#      BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF
# 1456            Unf           0.0        725.0          725.0
# 1547            Unf           0.0       1595.0         1595.0
# 1997            Unf           0.0        936.0          936.0

# %% [markdown]
# To address the null values in the basement variables: <br>
# To remove row 1147 as only BsmtFin Type 2 info is missing in this row

# %%
df_train_clean[["Bsmt Qual", "Bsmt Cond", "Bsmt Exposure", "BsmtFin Type 1", "BsmtFin SF 1", "BsmtFin Type 2", "BsmtFin SF 2", "Bsmt Unf SF", "Total Bsmt SF"]].iloc[[1147]]
# Out:
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 1147        Gd        TA            No            GLQ        1124.0
#
#      BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF
# 1147            NaN         479.0       1603.0         3206.0

# %% [markdown]
# Drop rows 1147, 1456, 1547 and 1997

# %%
df_train_clean = df_train_clean.drop(df_train_clean.index[[1147, 1456, 1547, 1997]])

# %% [markdown]
# To reset index after dropping the rows

# %%
df_train_clean = df_train_clean.reset_index(drop = True)

# %% [markdown]
# For basement variables, to replace null numerical variables to 0.0 and categorial variables to No/No Basement

# %%
df_train_clean['Bsmt Qual'] = df_train_clean['Bsmt Qual'].fillna("No Basement")
df_train_clean['Bsmt Cond'] = df_train_clean['Bsmt Cond'].fillna("No Basement")
df_train_clean['Bsmt Exposure'] = df_train_clean['Bsmt Exposure'].fillna("No")
df_train_clean['BsmtFin Type 1'] = df_train_clean['BsmtFin Type 1'].fillna("No Basement")
df_train_clean['BsmtFin Type 2'] = df_train_clean['BsmtFin Type 2'].fillna("No Basement")
df_train_clean['BsmtFin SF 1'] = df_train_clean['BsmtFin SF 1'].fillna(0.0)
df_train_clean['BsmtFin SF 2'] = df_train_clean['BsmtFin SF 2'].fillna(0.0)
df_train_clean['Bsmt Unf SF'] = df_train_clean['Bsmt Unf SF'].fillna(0.0)
df_train_clean['Total Bsmt SF'] = df_train_clean['Total Bsmt SF'].fillna(0.0)
df_train_clean['Bsmt Full Bath'] = df_train_clean['Bsmt Full Bath'].fillna(0.0)
df_train_clean['Bsmt Half Bath'] = df_train_clean['Bsmt Half Bath'].fillna(0.0)

# %% [markdown]
# For fireplace qu, fireplaces number is 0, hence to replace null with No Fireplace

# %%
df_train_clean[df_train_clean["Fireplace Qu"].isnull()].head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   109  533352170           60        RL          68.0     13517   Pave
# 2   153  535304180           20        RL          68.0      7922   Pave
# 3   318  916386060           60        RL          73.0      9802   Pave
# 4   255  906425045           50        RL          82.0     14235   Pave
# 6  2827  908186070          180        RM          35.0      3675   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
# 6       Reg          Lvl    AllPub     Inside        Gtl      Edwards
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %% [markdown]
# Replace null values in fireplace qu to No Fireplace

# %%
df_train_clean['Fireplace Qu'] = df_train_clean['Fireplace Qu'].fillna("No Fireplace")

# %% [markdown]
# Take a look at garage variables which have null values

# %%
df_train_clean[df_train_clean["Garage Yr Blt"].isnull()].head()
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 28   2243  911103060          190   C (all)          75.0      8250   Pave
# 53    330  923226250          160        RM          21.0      1476   Pave
# 65   2278  923202134           20        RL          70.0      8402   Pave
# 79   2235  910201050           50        RM          50.0      7288   Pave
# 101  2084  905476170           30        RL          58.0      9098   Pave
#
#     Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 28        Reg          Lvl    AllPub     Inside        Gtl       IDOTRR
# 53        Reg          Lvl    AllPub     Inside        Gtl      MeadowV
# 65        Reg          Lvl    AllPub     Inside        Gtl      Mitchel
# 79        Reg          Lvl    AllPub     Inside        Gtl       IDOTRR
# 101       IR1          Lvl    AllPub     Inside        Gtl      Edwards
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %% [markdown]
# To remove row 1709 as garage type info is found but other garage info is missing (null values)

# %%
df_train_clean[["Garage Type", "Garage Yr Blt", "Garage Finish", "Garage Cars", "Garage Area", "Garage Qual", "Garage Cond"]].iloc[[1709]]
# Out:
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 1709      Detchd            NaN           NaN          NaN          NaN
#
#      Garage Qual Garage Cond
# 1709         NaN         NaN

# %%
df_train_clean = df_train_clean.drop([df_train_clean.index[1709]])

# %% [markdown]
# Reset Index after dropping row

# %%
df_train_clean = df_train_clean.reset_index(drop = True)

# %% [markdown]
# For garage variables, to replace null numerical variables to 0.0 and categorial variables to No Basement

# %%
df_train_clean['Garage Yr Blt'] = df_train_clean['Garage Yr Blt'].fillna(0.0)
df_train_clean['Garage Type'] = df_train_clean['Garage Type'].fillna("No Garage")
df_train_clean['Garage Finish'] = df_train_clean['Garage Finish'].fillna("No Garage")
df_train_clean['Garage Qual'] = df_train_clean['Garage Qual'].fillna("No Garage")
df_train_clean['Garage Cond'] = df_train_clean['Garage Cond'].fillna("No Garage")

# %% [markdown]
# All null values have been dealt with! :)

# %%
df_train_clean[df_train_clean.columns[df_train_clean.isnull().any()]].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ## Check for Duplicates

# %% [markdown]
# To check for duplicates and remove if any

# %%
df_train_clean.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Rename Column Names

# %%
def rename(dataframe):
    dataframe.columns = dataframe.columns.str.lower().str.replace(" ", "_")
    print(dataframe.columns)

rename(df_train_clean)
# Out:
# Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area',
#        'street', 'lot_shape', 'land_contour', 'utilities', 'lot_config',
#        'land_slope', 'neighborhood', 'condition_1', 'condition_2', 'bldg_type',
#        'house_style', 'overall_qual', 'overall_cond', 'year_built',
#        'year_remod/add', 'roof_style', 'roof_matl', 'exterior_1st',
#        'exterior_2nd', 'mas_vnr_type', 'mas_vnr_area', 'exter_qual',
#        'exter_cond', 'foundation', 'bsmt_qual', 'bsmt_cond', 'bsmt_exposure',
#        'bsmtfin_type_1', 'bsmtfin_sf_1', 'bsmtfin_type_2', 'bsmtfin_sf_2',
#        'bsmt_unf_sf', 'total_bsmt_sf', 'heating', 'heating_qc', 'central_air',
#        'electrical', '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf',
#        'gr_liv_area', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath',
#        'half_bath', 'bedroom_abvgr', 'kitchen_abvgr', 'kitchen_qual',
#        'totrms_abvgrd', 'functional', 'fireplaces', 'fireplace_qu',
# ...

# %%
#rename some other columns with numbers at the front and other symbols in the feature names

df_train_clean.rename(columns={
    '1st_flr_sf': 'first_flr_sf',
    '2nd_flr_sf': 'second_flr_sf',
    '3ssn_porch': 'three_ssn_porch',
    'year_remod/add': 'year_remod_add'
}, inplace=True)

# %% [markdown]
# ## Save Clean Train File as New csv File

# %% [markdown]
# All null values/duplicate data have been dealt with and columns renamed

# %%
df_train_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2046 entries, 0 to 2045
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2046 non-null   int64
#  1   pid              2046 non-null   int64
#  2   ms_subclass      2046 non-null   int64
#  3   ms_zoning        2046 non-null   object
#  4   lot_frontage     2046 non-null   float64
#  5   lot_area         2046 non-null   int64
#  6   street           2046 non-null   object
#  7   lot_shape        2046 non-null   object
#  8   land_contour     2046 non-null   object
#  9   utilities        2046 non-null   object
#  10  lot_config       2046 non-null   object
#  11  land_slope       2046 non-null   object
#  12  neighborhood     2046 non-null   object
#  13  condition_1      2046 non-null   object
#  14  condition_2      2046 non-null   object
#  15  bldg_type        2046 non-null   object
# ...

# %% [markdown]
# Save clean df_train file as a new csv file

# %%
df_train_clean.to_csv('../Dataset/train_clean.csv', index = False)

# %% [markdown]
# # 5. Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |id|integer|train.csv|Observation number|
# |pid|integer|train.csv|Parcel identification number  - can be used with city web site for parcel review|
# |ms_subclass|integer|train.csv|Identifies the type of dwelling involved in the sale|
# |ms_zoning|object|train.csv|Identifies the general zoning classification of the sale|
# |lot_frontage|float|train.csv|Linear feet of street connected to property|
# |lot_area|integer|train.csv|Lot size in square feet|
# |street|object|train.csv|Type of road access to property|
# |lot_shape|object|train.csv|General shape of property|
# |land_contour|object|train.csv|Flatness of the property|
# |utilities|object|train.csv|Type of utilities available|
# |lot_config|object|train.csv|Lot configuration|
# |land_slope|object|train.csv|Slope of property|
# |neighborhood|object|train.csv|Physical locations within Ames city limits|
# |condition_1|object|train.csv|Proximity to various conditions|
# |condition_2|object|train.csv|Proximity to various conditions (if more than one is present)|
# |bldg_type|object|train.csv|Type of dwelling|
# |house_style|object|train.csv|Style of dwelling|
# |overall_qual|integer|train.csv|Rates the overall material and finish of the house|
# |overall_cond|integer|train.csv|Rates the overall condition of the house|
# |year_built|integer|train.csv|Original construction date|
# |year_remod_add|integer|train.csv|Remodel date (same as construction date if no remodeling or additions)|
# |roof_style|object|train.csv|Type of roof|
# |roof_matl|object|train.csv|Roof material|
# |exterior_1st|object|train.csv|Exterior covering on house|
# |exterior_2nd|object|train.csv|Exterior covering on house (if more than one material)|
# |mas_vnr_type|object|train.csv|Masonry veneer type|
# |mas_vnr_area|float|train.csv|Masonry veneer area in square feet|
# |exter_qual|object|train.csv|Evaluates the quality of the material on the exterior|
# |exter_cond|object|train.csv|Evaluates the present condition of the material on the exterior|
# |foundation|object|train.csv|Type of foundation|
# |bsmt_qual|object|train.csv|Evaluates the height of the basement|
# |bsmt_cond|object|train.csv|Evaluates the general condition of the basement|
# |bsmt_exposure|object|train.csv|Refers to walkout or garden level walls|
# |bsmtfin_type_1|object|train.csv|Rating of basement finished area|
# |bsmtfin_sf_1|float|train.csv|Type 1 finished square feet|
# |bsmtfin_type_2|object|train.csv|Rating of basement finished area (if multiple types)|
# |bsmtfin_sf_2|float|train.csv|Type 2 finished square feet|
# |bsmt_unf_sf|float|train.csv|Unfinished square feet of basement area|
# |total_bsmt_sf|float|train.csv|Total square feet of basement area|
# |heating|object|train.csv|Type of heating|
# |heating_qc|object|train.csv|Heating quality and condition|
# |central_air|object|train.csv|Central air conditioning|
# |electrical|object|train.csv|Electrical system|
# |first_flr_sf|integer|train.csv|First Floor square feet|
# |second_flr_sf|integer|train.csv|Second floor square feet|
# |low_qual_fin_sf|integer|train.csv|Low quality finished square feet (all floors)|
# |gr_liv_area|integer|train.csv|Above grade (ground) living area square feet|
# |bsmt_full_bath|float|train.csv|Basement full bathrooms|
# |bsmt_half_bath|float|train.csv|Basement half bathrooms|
# |full_bath|integer|train.csv|Full bathrooms above grade|
# |half_bath|integer|train.csv|Half baths above grade|
# |bedroom_abvgr|integer|train.csv|Bedrooms above grade (does NOT include basement bedrooms)|
# |kitchen_abvgr|integer|train.csv|Kitchens above grade|
# |kitchen_qual|object|train.csv|Kitchen quality|
# |totrms_abvgrd|integer|train.csv|Total rooms above grade (does not include bathrooms)|
# |functional|object|train.csv|Home functionality (Assume typical unless deductions are warranted)|
# |fireplaces|integer|train.csv|Number of fireplaces|
# |fireplace_qu|object|train.csv|Fireplace quality|
# |garage_type|object|train.csv|Garage location|
# |garage_yr_blt|float|train.csv|Year garage was built|
# |garage_finish|object|train.csv|Interior finish of the garage|
# |garage_cars|float|train.csv|Size of garage in car capacity|
# |garage_area|float|train.csv|Size of garage in square feet|
# |garage_qual|object|train.csv|Garage quality|
# |garage_cond|object|train.csv|Garage condition|
# |paved_drive|object|train.csv|Paved driveway|
# |wood_deck_sf|integer|train.csv|Wood deck area in square feet|
# |open_porch_sf|integer|train.csv|Open porch area in square feet|
# |enclosed_porch|integer|train.csv|Enclosed porch area in square feet|
# |three_ssn_porch|integer|train.csv|Three season porch area in square feet|
# |screen_porch|integer|train.csv|Screen porch area in square feet|
# |pool_area|integer|train.csv|Pool area in square feet|
# |misc_val|integer|train.csv|$Value of miscellaneous feature|
# |mo_sold|integer|train.csv|Month Sold (MM)|
# |yr_sold|integer|train.csv|Year Sold (YYYY)|
# |sale_type|object|train.csv|Type of sale|
# |saleprice|integer|train.csv|Sale price $$|
#
# <br>
#
# For a more detailed breakdown of each feature, to refer to http://jse.amstat.org/v19n3/decock/DataDocumentation.txt
